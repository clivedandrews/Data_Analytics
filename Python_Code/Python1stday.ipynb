# %% [markdown]
# ## statements in python

# %% [markdown]
# # Python

# %% [markdown]
# ## Python

# %% [markdown]
# ### Python

# %% [markdown]
# # Python

# %%
x =10
x
# Out:
# 10

# %%
x
# Out:
# 10

# %%
id(x)
# Out:
# 1916131696

# %%
y = 10

# %%
y
# Out:
# 10

# %%
id(y)
# Out:
# 1916131696

# %%
x =15
x
# Out:
# 15

# %%
id(x)
# Out:
# 1916131776

# %%
hex(id(x))
# Out:
# '0x7235d9c0'

# %%
2+5
# Out:
# 7

# %%
5-7
# Out:
# -2

# %%
5*7
# Out:
# 35

# %%
16/4
# Out:
# 4.0

# %%
13/4
# Out:
# 3.25

# %%
13//4,13%4
# Out:
# (3, 1)

# %%
-13//4,-13%4
# Out:
# (-4, 3)

# %%
13//-4,13%-4
# Out:
# (-4, -3)

# %%
-13//-4,-13%-4
# Out:
# (3, -1)

# %%
a=3*1.1
b=3.3

# %%
a==b
# Out:
# False

# %%
3*1.1
# Out:
# 3.3000000000000003

# %%
5**3
# Out:
# 125

# %%
import math

# %%
math.isclose(a,b)
# Out:
# True

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'pi',
#  'pow',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
a = 10
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b = 10.009

# %%
type(b)
# Out:
# float

# %%
False and True or True
# Out:
# True

# %%
False or True and False
# Out:
# False

# %%
False and (True or False)
# Out:
# False

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# ## Data structures

# %%
a = 10,100,20
a
# Out:
# (10, 100, 20)

# %%
list1 = [1,2,3,4,5]
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
type(list1)
# Out:
# list

# %%
tup1 = (10,20,30,40,50)
tup1
# Out:
# (10, 20, 30, 40, 50)

# %%
type(tup1)
# Out:
# tuple

# %%
str1 = 'hello world'
str1
# Out:
# 'hello world'

# %%
type(str1)
# Out:
# str

# %%
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
list1[2]
# Out:
# 3

# %%
list1[-2]
# Out:
# 4

# %%
str1
# Out:
# 'hello world'

# %%
str1[3]
# Out:
# 'l'

# %%
str1[4]
# Out:
# 'o'

# %%
str1[8]
# Out:
# 'r'

# %%
str1[-1]
# Out:
# 'd'

# %%
tup1
# Out:
# (10, 20, 30, 40, 50)

# %%
tup1[-1]
# Out:
# 50

# %%
tup1[3]
# Out:
# 40

# %% [markdown]
# ## Slicing

# %%
str1
# Out:
# 'hello world'

# %%
str1[1:3]
# Out:
# 'el'

# %%
str1[0:5]
# Out:
# 'hello'

# %%
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
list1[3:5]
# Out:
# [4, 5]

# %%
list1[2:]
# Out:
# [3, 4, 5]

# %%
list1[:4]
# Out:
# [1, 2, 3, 4]

# %%
list1[:]
# Out:
# [1, 2, 3, 4, 5]

# %%
list1[1:4:2]
# Out:
# [2, 4]

# %%
list1[2:4:3]
# Out:
# [3]

# %%
list1[::-1]
# Out:
# [5, 4, 3, 2, 1]

# %%
list1[::-2]
# Out:
# [5, 3, 1]

# %%
str1[::-2]
# Out:
# 'drwolh'

# %%
str ='welcome'

# %%
str[::1]
# Out:
# 'welcome'

# %%
str[::2]
# Out:
# 'wloe'

# %%
str[::3]
# Out:
# 'wce'

# %%
str[2:4:2]
# Out:
# 'l'

# %%
str1
# Out:
# 'hello world'

# %%
list(enumerate(str1))
# Out:
# [(0, 'h'),
#  (1, 'e'),
#  (2, 'l'),
#  (3, 'l'),
#  (4, 'o'),
#  (5, ' '),
#  (6, 'w'),
#  (7, 'o'),
#  (8, 'r'),
#  (9, 'l'),
#  (10, 'd')]
